# %% [markdown]
# # Models
#
#
# <img src="../images/models.png" alt="Shiny dashboard screenshot" width="700">
#
#
# To test the performance, we used 11 LLMs of varying sizes available via the Together.AI API. For evaluation, we employed the Gemini API, which served as an LLM judge to compare models' output. Because LLMs tend to score their own responses higher than those of other models, we did not test Gemini in experiments.

# %% [markdown]
# ## Characteristics of Models
#
# | Model | Parameters | Characteristics |
# | --- | --- | --- |
# | LG AI ExaOne 3.5 | 32 billion | Dense architecture, instruction-tuned with 32k token context length. |
# | Meta Llama 3.2 3B Instruct Turbo | 3 billion | Dense architecture, auto-regressive transformer, instruction-tuned, 128K-token context length. |
# | Meta Llama 3.1 8B Instruct Turbo | 8 billion | Dense architecture, auto-regressive transformer, instruction-tuned, 128K-token context length. |
# | Meta Llama 4 Scout 17B-16E Instruct | 17 billion activated parameters across 16 experts; total size approximately 109B parameters | Auto-regressive Mixture-of-Experts (MoE) architecture, instruction-tuned, 10M-token context length. |
# | Meta Llama 4 Maverick 17B-128E-Instruct-FP8 | 17 billion activated parameters across 128 experts; total size approximately 400B parameters | Mixture-of-Experts (MoE) architecture, instruction-tuned, 1M-token context length, FP8 quantized. |
# | Mistral Small 24B Instruct 2501 | 24 billion | Mixture-of-Experts architecture, instruction-tuned, 32K-token context length. |
# | Moonshot AI Kimi K2 | 32 billion activated parameters, 1 trillion total parameters | Mixture-of-Experts architecture, instruction-tuned agentic model, open-source, 128K-token context length. |
# | Qwen 2.5-72B-Instruct-Turbo | 72.7 billion | Dense decoder-only architecture, instruction-tuned, 128K-token context length. |
# | Qwen3 235B-A22B-fp8 | 22 billion activated parameters, 235B total parameters | Mixture-of-Experts architecture, 32K-token context length. |

# %% [markdown]
# # Short description of models

# %% [markdown]
# ### DeepSeek V3
#
# DeepSeek-V3 is a Mixture-of-Experts (MoE) language model with 671 billion total parameters, activating 37 billion parameters for each token. Its post-training involved an knowledge distillation methodology from the DeepSeek R1 reasoning model.
# Source:
# [HuggingFace Model Card](https://huggingface.co/deepseek-ai/DeepSeek-V3)

# %% [markdown]
# ### ExaOne 3.5 32B
# The EXAONE 3.5 language models are based on the decoder-only Transformer architecture. ExaOne 3.5 32B is the instruction-tuned 32B language model with the following features:
# * Number of Parameters (without embeddings): 30.95B
# * Number of Layers: 64
# * Number of Attention Heads: GQA with 40 Q-heads and 8 KV-heads
# * Vocab Size: 102,400 (?)
# * Context Length: 32,768 tokens
#
# Source:
# [Technical Report](https://arxiv.org/pdf/2412.04862)
# [HuggingFace model card](https://huggingface.co/LGAI-EXAONE/EXAONE-3.5-32B-Instruct)

# %% [markdown]
# ### Meta Llama 4 Scout (17B x 16E)
# The Llama 4 models are auto-regressive language models that use a mixture-of-experts (MoE) architecture and incorporate early fusion for native multimodality. Llama Scout is a 17 billion parameter model with 16 experts.
# * Parameters: 17B (Activated) 109B (Total)

# %% [markdown]
# ### Meta Llama 4 Maverick (17B x 128E)
# Llama 4 series, Llama 4 Maverick is a 17 billion parameter model with 128 experts.
#
# * Parameters: 17B (Activated) 400B (Total)
#
# Source:
# [HuggingFace Modle Card](https://huggingface.co/meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8)
